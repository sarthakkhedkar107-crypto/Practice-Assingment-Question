# %% [markdown]
# # practice list

# %% [raw]
# 1. Deep Indexing Practice Given the list: data = ["a", "b", ["c", ["d", "e", "target"], "f"], "g"]
# • Task: Write the code to extract the word "target".

# %%
data = ["a", "b", ["c", ["d", "e", "target"], "f"], "g"]
data
# Out:
# ['a', 'b', ['c', ['d', 'e', 'target'], 'f'], 'g']

# %%
data[2][1][2]
# Out:
# 'target'

# %% [markdown]
#  # 2. Append vs. Extend Given: colors = ["red", "blue"]

# %% [raw]
# •	Task A: Add the list ["green", "yellow"] so the result is ['red', 'blue', ['green', 'yellow']].
# •	Task B: Add the same list so the result is ['red', 'blue', 'green', 'yellow'].
# •	Solution A:colors.append(["green", "yellow"])
# •	Solution B:colors.extend(["green", "yellow"])

# %%
a=['red','blue']
a
# Out:
# ['red', 'blue']

# %%
a.append('green','yellow)

# %%
a
# Out:
# ['red', 'blue']

# %%
b=['green','yellow']

# %%
b
# Out:
# ['green', 'yellow']

# %%
b.extend(['red','blue'])

# %%
b
# Out:
# ['green', 'yellow']

# %%
matrix = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
matrix
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
matrix[1][2]
# Out:
# 6

# %%
nums=[10,20,40]
nums.insert(2, 30)
nums
# Out:
# [10, 20, 30, 40]

# %% [markdown]
# # 5. Mixed Data TypesGiven: mixed = [1, "Python", [True, False]]
# # •	Task: Change False to None.

# %%
mixed = [1, "Python", [True, False]]
mixed
# Out:
# [1, 'Python', [True, False]]

# %%
mixed[2][1] = None

# %%
mixed
# Out:
# [1, 'Python', [True, None]]

# %% [markdown]
# # Part 1: Nested List Indexing
# # Based on the structure shown in your notebook, here are examples for practicing deep indexing

# %% [raw]
# Example 1: Accessing Triple-Nested Items Given the list: nested = [1, [2, 3, [4, 5, 6]], 7]

# %%
nested = [1, [2, 3, [4, 5, 6]], 7]
nested
# Out:
# [1, [2, 3, [4, 5, 6]], 7]

# %%
nested[1][0]
# Out:
# 2

# %%
nested[1][2]
# Out:
# [4, 5, 6]

# %%
nested[1][2][1]
# Out:
# 5

# %% [markdown]
# # Example 2: Matrix-Style Access Given a 3x3 matrix: matrix = [[10, 20, 30], [40, 50, 60], [70, 80, 90]]

# %% [raw]
# # •	Access the middle row:matrix[1]
# # •	Access the number 90:matrix[2][2]
# # •	Access the number 40:matrix[1][0]

# %%
matrix = [[10, 20, 30], [40, 50, 60], [70, 80, 90]]
matrix
# Out:
# [[10, 20, 30], [40, 50, 60], [70, 80, 90]]

# %%
matrix[1]
# Out:
# [40, 50, 60]

# %%
matrix[2][2]
# Out:
# 90

# %%
matrix[1][0]
# Out:
# 40

# %% [markdown]
# # Part 2: List Methods (append, extend, insert)
# # Your notebook highlights how these methods change a list differently.
# # Example 3: append() vs. extend() Let fruits = ['apple', 'banana'].

# %%
fruits = ['apple', 'banana']
fruits
# Out:
# ['apple', 'banana']

# %%
fruits.append(['kiwi','mango'])
print(fruits)
# Out:
# ['apple', 'banana', ['kiwi', 'mango'], ['kiwi', 'mango'], ['kiwi', 'mango'], ['kiwi', 'mango'], ['kiwi', 'mango']]

# %%
fruits.extend(['kiwi','mango'])
fruits
# Out:
# ['apple',
#  'banana',
#  ['kiwi', 'mango'],
#  ['kiwi', 'mango'],
#  ['kiwi', 'mango'],
#  ['kiwi', 'mango'],
#  ['kiwi', 'mango'],
#  'kiwi',
#  'mango']

# %%
n= [10, 20, 40, 50]
n
# Out:
# [10, 20, 40, 50]

# %%
n.insert(2,30)

# %%
n
# Out:
# [10, 20, 30, 40, 50]

# %% [markdown]
# # Part 3: Advanced Practice Challenges
#  # Try to predict the output of the following operations based on the logic in your notebook:
# # 1.	Challenge: What is the output of l[2][1] if l = [5, 6, [7, 8, 9], 10]?
# # o	Answer:8.

# %%
l=[5,6,[7,8,9],10]
l
# Out:
# [5, 6, [7, 8, 9], 10]

# %%
l[2][1]
# Out:
# 8

# %% [markdown]
#  # 2.	Challenge: If data = [1, 2], what does data.extend([3, [4, 5]]) produce?
# # o	Answer:[1, 2, 3, [4, 5]] (The inner list [4, 5] remains a single element).

# %%
data = [1, 2]
data.extend([3, [4, 5]])
print(data)
# Out:
# [1, 2, 3, [4, 5]]

# %% [markdown]
# # 3.	Challenge: How do you change 'hello' to 'hi' in x = [10, [20, 'hello']]?
# # o	Answer:x[1][1] = 'hi'

# %%
x=[10,[20,'helloe']]
x
# Out:
# [10, [20, 'helloe']]

# %%
x[1][1]='hi'
x
# Out:
# [10, [20, 'hi']]

# %% [markdown]
# # 4.	Challenge: Given vals = [1, 2, 3], what is the result of vals.insert(0, [0])?
#  # o	Answer:[[0], 1, 2, 3] (Inserts the list at index 0).

# %%
vals=[1,2,3]
vals
# Out:
# [1, 2, 3]

# %%
vals.insert(0,[0])
vals
# Out:
# [[0], [0], 1, 2, 3]

# %% [markdown]
#  # 5.	Challenge: Given a = [1, 2] and b = [3, 4], what is a.append(b) followed by len(a)?
# # o	Answer:[1, 2, [3, 4]] and the length is 3.

# %%
a=[1,2]
b=[3,4]
a.append(b)

# %%
a
# Out:
# [1, 2, [3, 4]]

# %%
len(a)
# Out:
# 3
