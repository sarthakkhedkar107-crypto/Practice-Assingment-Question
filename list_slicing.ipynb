# %%
l = [10, 20, 30, 40, 50, 60, 70, 80]
l
# Out:
# [10, 20, 30, 40, 50, 60, 70, 80]

# %%
l[2:5]
# Out:
# [30, 40, 50]

# %%
l[:4]
# Out:
# [10, 20, 30, 40]

# %%
l[5:]
# Out:
# [60, 70, 80]

# %%
l[::2]
# Out:
# [10, 30, 50, 70]

# %%
l[::-1]
# Out:
# [80, 70, 60, 50, 40, 30, 20, 10]

# %%
l[6:1:-2]
# Out:
# [70, 50, 30]

# %% [markdown]
# # Part B: Nested Lists

# %%
n = [1, 2, [100, 200, [300, 400]], 5]
n
# Out:
# [1, 2, [100, 200, [300, 400]], 5]

# %%
n[2]
# Out:
# [100, 200, [300, 400]]

# %%
n[2][1]
# Out:
# 200

# %%
n[2][2][1]
# Out:
# 400

# %%
n[2][1]=250

# %%
n
# Out:
# [1, 2, [100, 250, [300, 400]], 5]

# %%
n[2][0:2]
# Out:
# [100, 250]

# %% [markdown]
# # Part C: Advanced & Mixed Concepts

# %%
data = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
data
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
data[1]
# Out:
# [4, 5, 6]

# %%
data[1][1:3]
# Out:
# [5, 6]

# %%
 #How do you access the number 9 using negative indexing?

data[-1][2]
# Out:
# 9

# %%
 # If x = [1, 2, 3], what is the difference between x.append([4, 5]) and x.extend([4, 5])?
x=[1,2,3]
x
# Out:
# [1, 2, 3]

# %%
x.append([4,5]) # appen add element in the from list it mean the element is add [4,5] is have seprate list

# %%
x
# Out:
# [1, 2, 3, [4, 5]]

# %%
x.extend([4,5]) # Extend add element in the from normal list it mean they dont have  element is add [4,5]  seprate list

# %%
x
# Out:
# [1, 2, 3, [4, 5], 4, 5]

# %%
 # Given: z = [10, 20, 50, 76, 89, 56, 87, 90]. What is z[-3::-1]?
z = [10, 20, 50, 76, 89, 56, 87, 90]
z
# Out:
# [10, 20, 50, 76, 89, 56, 87, 90]

# %%
z[-3::-1]
# Out:
# [56, 89, 76, 50, 20, 10]

# %% [markdown]
#  # Create a nested list where the first element is a string, and the second element is a slice of [1, 2, 3, 4, 5].

# %%
numbers = [1, 2, 3, 4, 5]

nested_list = ["Python", numbers[1:4]]

print(nested_list)
# Out:
# ['Python', [2, 3, 4]]
